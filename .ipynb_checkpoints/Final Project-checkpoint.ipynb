# %%
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn as seabornInstance
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
dataset = pd.read_csv("co2emission.csv")
dataset
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 50593     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 50594     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 50595     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 50596     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 50597     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
new_data = dataset[["country", "year", "co2_per_capita"]]
new_data.head()
# Out:
#        country  year  co2_per_capita
# 0  Afghanistan  1850             NaN
# 1  Afghanistan  1851             NaN
# 2  Afghanistan  1852             NaN
# 3  Afghanistan  1853             NaN
# 4  Afghanistan  1854             NaN

# %%
europe = new_data[new_data["country"].isin(["Austria","Andorra","Armenia","Austria","Azerbaijan", 
                                            "Belarus","Belgium","Bosnia and Hersegovina","Bulgaria",
                                            "Croatia","Cyprus","Czechia",
                                            "Denmark",
                                            "Estonia",
                                            "Finland","France",
                                            "Georgia","Germany","Greece",
                                            "Hungary",
                                            "Iceland","Ireland","Italy",
                                           "Kazakhstan","Kosovo",
                                           "Latvia","Liechtenstein","Lithuania","Luxembourg",
                                           "Malta","Moldova","Monaco","Montenegro",
                                           "Netherlands","North Macedonia","Norway",
                                           "Poland","Portugal",
                                          "Romania","Russia",
                                           "San Marino","Serbia","Slovakia","Spain","Sweden","Switzerland",
                                           "Turkey",
                                           "Ukraine", "United Kingdom"])]
europe.head(1000)
# Out:
#       country  year  co2_per_capita
# 1304  Andorra  1750           0.000
# 1305  Andorra  1751             NaN
# 1306  Andorra  1752             NaN
# 1307  Andorra  1753             NaN
# 1308  Andorra  1754             NaN
# ...       ...   ...             ...
# 5005  Belarus  2013           6.617
# 5006  Belarus  2014           6.566
# 5007  Belarus  2015           6.061
# 5008  Belarus  2016           5.988
# 5009  Belarus  2017           6.105
#
# [1000 rows x 3 columns]

# %%
print(europe.isnull())
# Out:
#        country   year  co2_per_capita
# 1304     False  False           False
# 1305     False  False            True
# 1306     False  False            True
# 1307     False  False            True
# 1308     False  False            True
# ...        ...    ...             ...
# 47932    False  False           False
# 47933    False  False           False
# 47934    False  False           False
# 47935    False  False           False
# 47936    False  False           False
#
# [8364 rows x 3 columns]

# %%
missing_counts = europe.isnull().sum()
print(missing_counts)
# Out:
# country              0
# year                 0
# co2_per_capita    1199
# dtype: int64

# %%
europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8364 entries, 1304 to 47936
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         8364 non-null   object
#  1   year            8364 non-null   int64
#  2   co2_per_capita  7165 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 261.4+ KB

# %%
# Interpolate missing values using cubic interpolation along the columns
europe_interpolated = europe.interpolate(method='cubic', axis=0)
europe_interpolated.head(1000)
# Out:
#       country  year  co2_per_capita
# 1304  Andorra  1750    0.000000e+00
# 1305  Andorra  1751   1.238958e-109
# 1306  Andorra  1752   2.086666e-109
# 1307  Andorra  1753   2.586597e-109
# 1308  Andorra  1754   2.782222e-109
# ...       ...   ...             ...
# 5005  Belarus  2013    6.617000e+00
# 5006  Belarus  2014    6.566000e+00
# 5007  Belarus  2015    6.061000e+00
# 5008  Belarus  2016    5.988000e+00
# 5009  Belarus  2017    6.105000e+00
#
# [1000 rows x 3 columns]

# %%
ireland = europe_interpolated.loc[(europe_interpolated["country"] == "Ireland")]
ireland.head(65)
# Out:
#        country  year  co2_per_capita
# 22153  Ireland  1850        0.057000
# 22154  Ireland  1851        0.052501
# 22155  Ireland  1852        0.048614
# 22156  Ireland  1853        0.045310
# 22157  Ireland  1854        0.042559
# ...        ...   ...             ...
# 22213  Ireland  1910        0.050000
# 22214  Ireland  1911        0.047689
# 22215  Ireland  1912        0.047570
# 22216  Ireland  1913        0.052000
# 22217  Ireland  1914        0.058000
#
# [65 rows x 3 columns]

# %%
sns.relplot(x="year", y="co2_per_capita", data = ireland);

# %%
ireland = europe.loc[(europe["country"] == "Ireland") & (europe["year"] >= 1990)]
ireland
# Out:
#        country  year  co2_per_capita
# 22293  Ireland  1990           9.452
# 22294  Ireland  1991           9.608
# 22295  Ireland  1992           9.493
# 22296  Ireland  1993           9.509
# 22297  Ireland  1994           9.788
# 22298  Ireland  1995          10.016
# 22299  Ireland  1996          10.389
# 22300  Ireland  1997          10.660
# 22301  Ireland  1998          11.066
# 22302  Ireland  1999          11.409
# 22303  Ireland  2000          12.006
# 22304  Ireland  2001          12.433
# 22305  Ireland  2002          11.833
# 22306  Ireland  2003          11.540
# 22307  Ireland  2004          11.450
# 22308  Ireland  2005          11.685
# 22309  Ireland  2006          11.241
# 22310  Ireland  2007          10.933
# 22311  Ireland  2008          10.638
# 22312  Ireland  2009           9.374
# 22313  Ireland  2010           9.237
# 22314  Ireland  2011           8.374
# 22315  Ireland  2012           8.375
# 22316  Ireland  2013           8.124
# ...

# %%
sns.relplot(x="year", y="co2_per_capita", data = ireland);

# %%
# Interpolate missing values using linear interpolation along the columns
europe_interpolated = europe.interpolate(method='linear', axis=0)
europe_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8364 entries, 1304 to 47936
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         8364 non-null   object
#  1   year            8364 non-null   int64
#  2   co2_per_capita  8364 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 261.4+ KB

# %%
europe.head(9000)
# Out:
#               country  year  co2_per_capita
# 1304          Andorra  1750           0.000
# 1305          Andorra  1751             NaN
# 1306          Andorra  1752             NaN
# 1307          Andorra  1753             NaN
# 1308          Andorra  1754             NaN
# ...               ...   ...             ...
# 47932  United Kingdom  2017           5.863
# 47933  United Kingdom  2018           5.716
# 47934  United Kingdom  2019           5.462
# 47935  United Kingdom  2020           4.865
# 47936  United Kingdom  2021           5.154
#
# [8364 rows x 3 columns]

# %%
europe_interpolated.head(1000)
#eu = new_data[new_data["country"].isin(["Ireland"])]
#eu.head(1000)
#eu = europe_interpolated[europe_interpolated["country"].isin(["Ireland"])]
#eu.head(1000)
# Out:
#       country  year  co2_per_capita
# 1304  Andorra  1750           0.000
# 1305  Andorra  1751           0.000
# 1306  Andorra  1752           0.000
# 1307  Andorra  1753           0.000
# 1308  Andorra  1754           0.000
# ...       ...   ...             ...
# 5005  Belarus  2013           6.617
# 5006  Belarus  2014           6.566
# 5007  Belarus  2015           6.061
# 5008  Belarus  2016           5.988
# 5009  Belarus  2017           6.105
#
# [1000 rows x 3 columns]

# %%
selected_rows = europe_interpolated[europe_interpolated['year'].between(1750, 2021)]
selected_rows.head(1000)
# Out:
#       country  year  co2_per_capita
# 1304  Andorra  1750           0.000
# 1305  Andorra  1751           0.000
# 1306  Andorra  1752           0.000
# 1307  Andorra  1753           0.000
# 1308  Andorra  1754           0.000
# ...       ...   ...             ...
# 5005  Belarus  2013           6.617
# 5006  Belarus  2014           6.566
# 5007  Belarus  2015           6.061
# 5008  Belarus  2016           5.988
# 5009  Belarus  2017           6.105
#
# [1000 rows x 3 columns]

# %%
# Grouping the DataFrame by the 'year' column
grouped_by_year = europe_interpolated.groupby('year')

# Looping through each group
for year, group in grouped_by_year:
    # Printing the year and the corresponding DataFrame for that year
    print(f"Year: {year}")
    print(group)
    print()  # Add a newline for clarity
# Out:
# Year: 1750
#               country  year  co2_per_capita
# 1304          Andorra  1750           0.000
# 21022         Iceland  1750           0.000
# 47665  United Kingdom  1750           1.007
#
# Year: 1751
#               country  year  co2_per_capita
# 1305          Andorra  1751          0.0000
# 21023         Iceland  1751          0.0000
# 47666  United Kingdom  1751          1.0083
#
# Year: 1752
#               country  year  co2_per_capita
# 1306          Andorra  1752          0.0000
# 21024         Iceland  1752          0.0000
# 47667  United Kingdom  1752          1.0096
#
# Year: 1753
#               country  year  co2_per_capita
# 1307          Andorra  1753          0.0000
# 21025         Iceland  1753          0.0000
# 47668  United Kingdom  1753          1.0109
#
# Year: 1754
#               country  year  co2_per_capita
# 1308          Andorra  1754          0.0000
# 21026         Iceland  1754          0.0000
# 47669  United Kingdom  1754          1.0122
#
# ...

# %%
selected_rows.loc[(selected_rows["year"] >= 1900)].head(10000)
# Out:
#               country  year  co2_per_capita
# 1454          Andorra  1900           0.000
# 1455          Andorra  1901           0.000
# 1456          Andorra  1902           0.000
# 1457          Andorra  1903           0.000
# 1458          Andorra  1904           0.000
# ...               ...   ...             ...
# 47932  United Kingdom  2017           5.863
# 47933  United Kingdom  2018           5.716
# 47934  United Kingdom  2019           5.462
# 47935  United Kingdom  2020           4.865
# 47936  United Kingdom  2021           5.154
#
# [5490 rows x 3 columns]

# %%
selected_rows.loc[(selected_rows["year"] >= 1900) | (selected_rows["country"] == "Ireland")].head(10000)
# Out:
#               country  year  co2_per_capita
# 1454          Andorra  1900           0.000
# 1455          Andorra  1901           0.000
# 1456          Andorra  1902           0.000
# 1457          Andorra  1903           0.000
# 1458          Andorra  1904           0.000
# ...               ...   ...             ...
# 47932  United Kingdom  2017           5.863
# 47933  United Kingdom  2018           5.716
# 47934  United Kingdom  2019           5.462
# 47935  United Kingdom  2020           4.865
# 47936  United Kingdom  2021           5.154
#
# [5540 rows x 3 columns]

# %%
countries = selected_rows.loc[(selected_rows["year"] >= 1900), "country"]
countries.head()
# Out:
# 1454    Andorra
# 1455    Andorra
# 1456    Andorra
# 1457    Andorra
# 1458    Andorra
# Name: country, dtype: object

# %%
europe_interpolated["year"].values
# Out:
# array([1750, 1751, 1752, ..., 2019, 2020, 2021], dtype=int64)

# %%
europe_interpolated.plot(x='co2_per_capita', y='year', style='o')
plt.title('CO2 Per Capita vs Year')
plt.xlabel('CO2 Per Capita')
plt.ylabel('Year')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(europe_interpolated['co2_per_capita']);
# Out:
# C:\Users\lsant\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
X = europe_interpolated['co2_per_capita'].values.reshape(-1,1)
y = europe_interpolated['year'].values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 0)

regressor = LinearRegression()
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
#To retrieve the intercept:
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# [1901.02862722]
# [[6.59906989]]

# %%
europe_interpolated.describe()
# Out:
#               year  co2_per_capita
# count  8364.000000     8364.000000
# mean   1926.565280        3.914328
# std      57.679948        4.569215
# min    1750.000000        0.000000
# 25%    1882.000000        0.330000
# 50%    1929.000000        2.363500
# 75%    1975.000000        6.281434
# max    2021.000000       41.048000

# %%
europe_interpolated.values
# Out:
# array([['Andorra', 1750, 0.0],
#        ['Andorra', 1751, 0.0],
#        ['Andorra', 1752, 0.0],
#        ...,
#        ['United Kingdom', 2019, 5.462],
#        ['United Kingdom', 2020, 4.865],
#        ['United Kingdom', 2021, 5.154]], dtype=object)
