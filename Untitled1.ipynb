# %%
import pandas as pd
dataset = pd.read_csv("co2emission.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pandas.plotting import autocorrelation_plot
from matplotlib import pyplot

# %%
new_data = dataset[["country", "year", "co2_per_capita"]]
new_data.head()
# Out:
#        country  year  co2_per_capita
# 0  Afghanistan  1850             NaN
# 1  Afghanistan  1851             NaN
# 2  Afghanistan  1852             NaN
# 3  Afghanistan  1853             NaN
# 4  Afghanistan  1854             NaN

# %%
#autocorrelation plot
autocorrelation_plot(new_data)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 #autocorrelation plot
# ----> 2 autocorrelation_plot(new_data)
#       3 pyplot.show()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_misc.py:508, in autocorrelation_plot(series, ax, **kwargs)
#     478 """
#     479 Autocorrelation plot for time series.
#     480
#    (...)
#     505     <AxesSubplot:title={'center':'width'}, xlabel='Lag', ylabel='Autocorrelation'>
#     506 """
#     507 plot_backend = _get_plot_backend("matplotlib")
# --> 508 return plot_backend.autocorrelation_plot(series=series, ax=ax, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:454, in autocorrelation_plot(series, ax, **kwds)
#     452     ax.set_xlim(1, n)
#     453     ax.set_ylim(-1.0, 1.0)
# --> 454 mean = np.mean(data)
#     455 c0 = np.sum((data - mean) ** 2) / n
#     457 def r(h):
#
# File <__array_function__ internals>:5, in mean(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440, in mean(a, axis, dtype, out, keepdims, where)
#    3437     else:
#    3438         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3440 return _methods._mean(a, axis=axis, dtype=dtype,
#    3441                       out=out, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\_methods.py:179, in _mean(a, axis, dtype, out, keepdims, where)
#     176         dtype = mu.dtype('f4')
#     177         is_float16_result = True
# --> 179 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     180 if isinstance(ret, mu.ndarray):
#     181     ret = um.true_divide(
#     182             ret, rcount, out=ret, casting='unsafe', subok=False)
#
# TypeError: can only concatenate str (not "int") to str

# %%
new_data = dataset[["country", "year", "co2_per_capita"]]
new_data.head()
# Out:
#        country  year  co2_per_capita
# 0  Afghanistan  1850             NaN
# 1  Afghanistan  1851             NaN
# 2  Afghanistan  1852             NaN
# 3  Afghanistan  1853             NaN
# 4  Afghanistan  1854             NaN

# %%
europe = new_data[new_data["country"].isin(["Austria","Andorra","Armenia","Austria","Azerbaijan", 
                                            "Belarus","Belgium","Bosnia and Hersegovina","Bulgaria",
                                            "Croatia","Cyprus","Czechia",
                                            "Denmark",
                                            "Estonia",
                                            "Finland","France",
                                            "Georgia","Germany","Greece",
                                            "Hungary",
                                            "Iceland","Ireland","Italy",
                                           "Kazakhstan","Kosovo",
                                           "Latvia","Liechtenstein","Lithuania","Luxembourg",
                                           "Malta","Moldova","Monaco","Montenegro",
                                           "Netherlands","North Macedonia","Norway",
                                           "Poland","Portugal",
                                          "Romania","Russia",
                                           "San Marino","Serbia","Slovakia","Spain","Sweden","Switzerland",
                                           "Turkey",
                                           "Ukraine", "United Kingdom"])]
europe.head(1000)
# Out:
#       country  year  co2_per_capita
# 1304  Andorra  1750           0.000
# 1305  Andorra  1751             NaN
# 1306  Andorra  1752             NaN
# 1307  Andorra  1753             NaN
# 1308  Andorra  1754             NaN
# ...       ...   ...             ...
# 5005  Belarus  2013           6.617
# 5006  Belarus  2014           6.566
# 5007  Belarus  2015           6.061
# 5008  Belarus  2016           5.988
# 5009  Belarus  2017           6.105
#
# [1000 rows x 3 columns]

# %%
dataset = europe.loc[(europe["year"] >= 1900)]
dataset
# Out:
#               country  year  co2_per_capita
# 1454          Andorra  1900           0.000
# 1455          Andorra  1901           0.000
# 1456          Andorra  1902           0.000
# 1457          Andorra  1903           0.000
# 1458          Andorra  1904           0.000
# ...               ...   ...             ...
# 47932  United Kingdom  2017           5.863
# 47933  United Kingdom  2018           5.716
# 47934  United Kingdom  2019           5.462
# 47935  United Kingdom  2020           4.865
# 47936  United Kingdom  2021           5.154
#
# [5490 rows x 3 columns]

# %%
missing_counts = dataset.isnull().sum()
print(missing_counts)
# Out:
# country             0
# year                0
# co2_per_capita    386
# dtype: int64

# %%
dataset.head(92)
# Out:
#       country  year  co2_per_capita
# 1454  Andorra  1900           0.000
# 1455  Andorra  1901           0.000
# 1456  Andorra  1902           0.000
# 1457  Andorra  1903           0.000
# 1458  Andorra  1904           0.000
# ...       ...   ...             ...
# 1541  Andorra  1987           0.000
# 1542  Andorra  1988           0.000
# 1543  Andorra  1989           0.000
# 1544  Andorra  1990           7.589
# 1545  Andorra  1991           7.334
#
# [92 rows x 3 columns]

# %%
europe = dataset.interpolate(method='linear', axis=0)
europe.head(92)
# Out:
#       country  year  co2_per_capita
# 1454  Andorra  1900           0.000
# 1455  Andorra  1901           0.000
# 1456  Andorra  1902           0.000
# 1457  Andorra  1903           0.000
# 1458  Andorra  1904           0.000
# ...       ...   ...             ...
# 1541  Andorra  1987           0.000
# 1542  Andorra  1988           0.000
# 1543  Andorra  1989           0.000
# 1544  Andorra  1990           7.589
# 1545  Andorra  1991           7.334
#
# [92 rows x 3 columns]

# %%
andorra = europe.loc[(europe["country"] == "Andorra")]
andorra.head(92)
# Out:
#       country  year  co2_per_capita
# 1454  Andorra  1900           0.000
# 1455  Andorra  1901           0.000
# 1456  Andorra  1902           0.000
# 1457  Andorra  1903           0.000
# 1458  Andorra  1904           0.000
# ...       ...   ...             ...
# 1541  Andorra  1987           0.000
# 1542  Andorra  1988           0.000
# 1543  Andorra  1989           0.000
# 1544  Andorra  1990           7.589
# 1545  Andorra  1991           7.334
#
# [92 rows x 3 columns]

# %%
missing_counts = europe.isnull().sum()
print(missing_counts)
# Out:
# country           0
# year              0
# co2_per_capita    0
# dtype: int64

# %%
sns.relplot(x="year", y="co2_per_capita", data = andorra);

# %%
sns.relplot(x="year", y="co2_per_capita", data = europe);

# %%
sns.relplot(x="year", y="co2_per_capita", data = grouped_europe);

# %%
# Interpolate missing values using linear interpolation along the columns
#europe_interpolated = grouped_europe.interpolate(method='linear', axis=0)
#europe_interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 1990 to 2018
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   co2_per_capita  29 non-null     float64
# dtypes: float64(1)
# memory usage: 464.0 bytes

# %%
#europe_interpolated
# Out:
#       co2_per_capita
# year
# 1990       10.380394
# 1991       10.128091
# 1992        9.372667
# 1993        9.047273
# 1994        8.775848
# 1995        8.491758
# 1996        8.716606
# 1997        8.467667
# 1998        8.322970
# 1999        8.137970
# 2000        8.179818
# 2001        8.369424
# 2002        8.418515
# 2003        8.773324
# 2004        8.843029
# 2005        8.781882
# 2006        8.884412
# 2007        8.885912
# 2008        8.629000
# 2009        7.931000
# 2010        8.284353
# 2011        8.011735
# 2012        7.783912
# 2013        7.583824
# 2014        7.372735
# 2015        7.235441
# 2016        7.240176
# 2017        7.322235
# 2018        7.248647

# %%
#europe_g = europe_interpolated.groupby('year').mean()
#europe_g
# Out:
#       co2_per_capita
# year
# 1990       10.380394
# 1991       10.128091
# 1992        9.372667
# 1993        9.047273
# 1994        8.775848
# 1995        8.491758
# 1996        8.716606
# 1997        8.467667
# 1998        8.322970
# 1999        8.137970
# 2000        8.179818
# 2001        8.369424
# 2002        8.418515
# 2003        8.773324
# 2004        8.843029
# 2005        8.781882
# 2006        8.884412
# 2007        8.885912
# 2008        8.629000
# 2009        7.931000
# 2010        8.284353
# 2011        8.011735
# 2012        7.783912
# 2013        7.583824
# 2014        7.372735
# 2015        7.235441
# 2016        7.240176
# 2017        7.322235
# 2018        7.248647
